# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import date

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90
lng_range = (-180, 180)

# Today's date for plots
today = str(date.today())

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
def get_current_weather(city, api_key):

    url = "http://api.openweathermap.org/data/2.5/weather"
    payload = {
        "appid": api_key,
        "q": city
    }
    
    r = requests.get(url, params=payload)

    if r.status_code == 200:
        return r.json()
    else:
        None

# %%
city_data = []

print('Beginning Data Retrieval\n-----------------------------')
i = 1

for city in cities:
    result = get_current_weather(city, api_key)
    if result:
        print("Processing Record " + str(i) + " of Unique Set | " + city)
        i += 1
        city_data.append(result)
    else:
        print("City not found. Skipping...")
print("-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Unique Set | mataura
# Processing Record 2 of Unique Set | chapais
# Processing Record 3 of Unique Set | alofi
# Processing Record 4 of Unique Set | katsuura
# Processing Record 5 of Unique Set | cabo san lucas
# Processing Record 6 of Unique Set | howard springs
# Processing Record 7 of Unique Set | jamestown
# Processing Record 8 of Unique Set | vanimo
# Processing Record 9 of Unique Set | hualmay
# Processing Record 10 of Unique Set | port elizabeth
# Processing Record 11 of Unique Set | butaritari
# Processing Record 12 of Unique Set | bambous virieux
# Processing Record 13 of Unique Set | kodiak
# Processing Record 14 of Unique Set | busselton
# Processing Record 15 of Unique Set | wajima
# Processing Record 16 of Unique Set | sitka
# Processing Record 17 of Unique Set | ushuaia
# Processing Record 18 of Unique Set | kapaa
# Processing Record 19 of Unique Set | mahebourg
# Processing Record 20 of Unique Set | rikitea
# City not found. Skipping...
# Processing Record 21 of Unique Set | albany
# Processing Record 22 of Unique Set | nishihara
# Processing Record 23 of Unique Set | concepcion del oro
# Processing Record 24 of Unique Set | tuktoyaktuk
# Processing Record 25 of Unique Set | punta arenas
# City not found. Skipping...
# Processing Record 26 of Unique Set | miass
# Processing Record 27 of Unique Set | merauke
# Processing Record 28 of Unique Set | saskylakh
# Processing Record 29 of Unique Set | rio grande
# Processing Record 30 of Unique Set | khatanga
# Processing Record 31 of Unique Set | east london
# Processing Record 32 of Unique Set | avarua
# Processing Record 33 of Unique Set | ust-omchug
# Processing Record 34 of Unique Set | college
# Processing Record 35 of Unique Set | comodoro rivadavia
# Processing Record 36 of Unique Set | marsa matruh
# Processing Record 37 of Unique Set | dicabisagan
# Processing Record 38 of Unique Set | tankhoy
# Processing Record 39 of Unique Set | biak
# Processing Record 40 of Unique Set | pisco
# Processing Record 41 of Unique Set | ponta do sol
# Processing Record 42 of Unique Set | meghri
# Processing Record 43 of Unique Set | hasaki
# Processing Record 44 of Unique Set | arraial do cabo
# City not found. Skipping...
# Processing Record 45 of Unique Set | bluff
# Processing Record 46 of Unique Set | carballo
# City not found. Skipping...
# Processing Record 47 of Unique Set | sorland
# Processing Record 48 of Unique Set | calbuco
# Processing Record 49 of Unique Set | qaanaaq
# Processing Record 50 of Unique Set | zadar
# Processing Record 51 of Unique Set | port alfred
# Processing Record 52 of Unique Set | miri
# Processing Record 53 of Unique Set | mar del plata
# Processing Record 54 of Unique Set | los llanos de aridane
# Processing Record 55 of Unique Set | tura
# City not found. Skipping...
# Processing Record 403 of Unique Set | samaipata
# City not found. Skipping...
# Processing Record 404 of Unique Set | votorantim
# Processing Record 405 of Unique Set | sorong
# Processing Record 406 of Unique Set | nizhnevartovsk
# Processing Record 407 of Unique Set | whitecourt
# Processing Record 408 of Unique Set | padang
# Processing Record 409 of Unique Set | manggar
# Processing Record 410 of Unique Set | calvinia
# Processing Record 411 of Unique Set | sochaczew
# Processing Record 412 of Unique Set | hovd
# Processing Record 413 of Unique Set | taltal
# Processing Record 414 of Unique Set | stanceni
# Processing Record 415 of Unique Set | itupiranga
# Processing Record 416 of Unique Set | jimma
# Processing Record 417 of Unique Set | udala
# Processing Record 418 of Unique Set | hervey bay
# Processing Record 419 of Unique Set | harlingen
# Processing Record 420 of Unique Set | katihar
# Processing Record 421 of Unique Set | najran
# Processing Record 422 of Unique Set | dudinka
# City not found. Skipping...
# Processing Record 423 of Unique Set | mount gambier
# Processing Record 424 of Unique Set | navalmoral de la mata
# Processing Record 425 of Unique Set | sungaipenuh
# City not found. Skipping...
# Processing Record 426 of Unique Set | isagarh
# Processing Record 427 of Unique Set | port keats
# Processing Record 428 of Unique Set | bubaque
# Processing Record 429 of Unique Set | sussex
# Processing Record 430 of Unique Set | vyazemskiy
# Processing Record 431 of Unique Set | lavrentiya
# Processing Record 432 of Unique Set | kirovskiy
# Processing Record 433 of Unique Set | kaduqli
# Processing Record 434 of Unique Set | palu
# Processing Record 435 of Unique Set | antigonish
# Processing Record 436 of Unique Set | tigpalay
# City not found. Skipping...
# Processing Record 437 of Unique Set | kilindoni
# Processing Record 438 of Unique Set | avila
# Processing Record 439 of Unique Set | wagar
# Processing Record 440 of Unique Set | verkhoyansk
# City not found. Skipping...
# Processing Record 441 of Unique Set | kysyl-syr
# Processing Record 442 of Unique Set | portland
# City not found. Skipping...
# Processing Record 443 of Unique Set | macau
# City not found. Skipping...
# Processing Record 444 of Unique Set | lazaro cardenas
# Processing Record 445 of Unique Set | nador
# Processing Record 446 of Unique Set | walvis bay
# Processing Record 447 of Unique Set | atar
# Processing Record 448 of Unique Set | vila franca do campo
# Processing Record 449 of Unique Set | shahr-e babak
# Processing Record 450 of Unique Set | ishinomaki
# Processing Record 451 of Unique Set | ladario
# Processing Record 452 of Unique Set | aripuana
# Processing Record 453 of Unique Set | bang sai
# Processing Record 454 of Unique Set | estelle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 455 of Unique Set | ponazyrevo
# Processing Record 456 of Unique Set | pacific grove
# Processing Record 457 of Unique Set | ola
# Processing Record 458 of Unique Set | andrychow
# Processing Record 459 of Unique Set | camopi
# Processing Record 460 of Unique Set | magadan
# Processing Record 461 of Unique Set | burnie
# City not found. Skipping...
# Processing Record 462 of Unique Set | sao miguel do araguaia
# Processing Record 463 of Unique Set | santo domingo
# Processing Record 464 of Unique Set | wuwei
# Processing Record 465 of Unique Set | reyes
# City not found. Skipping...
# Processing Record 466 of Unique Set | zapolyarnyy
# Processing Record 467 of Unique Set | kokkarion
# Processing Record 468 of Unique Set | harqalah
# Processing Record 469 of Unique Set | giyon
# Processing Record 470 of Unique Set | rurrenabaque
# Processing Record 471 of Unique Set | tautira
# Processing Record 472 of Unique Set | ranong
# Processing Record 473 of Unique Set | hendek
# Processing Record 474 of Unique Set | sao filipe
# Processing Record 475 of Unique Set | buraydah
# Processing Record 476 of Unique Set | mansa
# Processing Record 477 of Unique Set | zaltan
# Processing Record 478 of Unique Set | colquiri
# Processing Record 479 of Unique Set | jinxi
# Processing Record 480 of Unique Set | maroantsetra
# Processing Record 481 of Unique Set | shenjiamen
# Processing Record 482 of Unique Set | diamantino
# Processing Record 483 of Unique Set | san quintin
# Processing Record 484 of Unique Set | melfi
# Processing Record 485 of Unique Set | carutapera
# Processing Record 486 of Unique Set | kirakira
# City not found. Skipping...
# Processing Record 487 of Unique Set | ballina
# Processing Record 488 of Unique Set | mucurapo
# Processing Record 489 of Unique Set | sept-iles
# Processing Record 490 of Unique Set | sola
# Processing Record 491 of Unique Set | qaqortoq
# Processing Record 492 of Unique Set | gorom-gorom
# Processing Record 493 of Unique Set | moose factory
# Processing Record 494 of Unique Set | makakilo city
# Processing Record 495 of Unique Set | ellisras
# Processing Record 496 of Unique Set | newcastle
# Processing Record 497 of Unique Set | nagapattinam
# Processing Record 498 of Unique Set | krasnoslobodsk
# Processing Record 499 of Unique Set | lufilufi
# Processing Record 500 of Unique Set | robertsport
# Processing Record 501 of Unique Set | houma
# Processing Record 502 of Unique Set | manakara
# Processing Record 503 of Unique Set | pujili
# Processing Record 504 of Unique Set | omboue
# Processing Record 505 of Unique Set | nicoya
# Processing Record 506 of Unique Set | wolverhampton
# Processing Record 507 of Unique Set | asifabad
# Processing Record 508 of Unique Set | naze
# Processing Record 509 of Unique Set | sobolevo
# City not found. Skipping...
# Processing Record 510 of Unique Set | boende
# Processing Record 511 of Unique Set | conway
# Processing Record 512 of Unique Set | sur
# City not found. Skipping...
# Processing Record 513 of Unique Set | petropavlovsk-kamchatskiy
# Processing Record 514 of Unique Set | karratha
# Processing Record 515 of Unique Set | xichang
# Processing Record 516 of Unique Set | nieuw amsterdam
# City not found. Skipping...
# Processing Record 517 of Unique Set | krasnoarmeysk
# Processing Record 518 of Unique Set | molde
# Processing Record 519 of Unique Set | mikhaylovka
# Processing Record 520 of Unique Set | gazanjyk
# Processing Record 521 of Unique Set | mayo
# Processing Record 522 of Unique Set | port-cartier
# Processing Record 523 of Unique Set | san miguel
# Processing Record 524 of Unique Set | the valley
# Processing Record 525 of Unique Set | caucaia
# Processing Record 526 of Unique Set | zuwarah
# Processing Record 527 of Unique Set | tadine
# Processing Record 528 of Unique Set | rio gallegos
# Processing Record 529 of Unique Set | talnakh
# Processing Record 530 of Unique Set | huarmey
# Processing Record 531 of Unique Set | aitape
# Processing Record 532 of Unique Set | rocha
# Processing Record 533 of Unique Set | george town
# Processing Record 534 of Unique Set | sinyavino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame([{
    'Name': d['name'],
    'Cloudiness': d['clouds']['all'],
    'Country': d['sys']['country'],
    'Date': d['dt'],
    'Humidity': d['main']['humidity'],
    'Lat': d['coord']['lat'],
    'Lng': d['coord']['lon'],
    'Temp': d['main']['temp_max'],
    'Wind': d['wind']['speed']
} for d in city_data])

df.head(10)
# Out:
#    Cloudiness Country        Date  Humidity    Lat     Lng            Name  \
# 0          89      NZ  1578329218        93 -46.19  168.86         Mataura
# 1          90      CA  1578329698        84  49.78  -74.86         Chapais
# 2          75      NU  1578329510       100 -19.06 -169.92           Alofi
# 3          75      JP  1578329698        75  33.93  134.50        Katsuura
# 4          40      MX  1578329428        59  22.89 -109.91  Cabo San Lucas
# 5         100      AU  1578329699        94 -12.50  131.05  Howard Springs
# 6           0      AU  1578329791        47 -33.21  138.60       Jamestown
# 7          63      PG  1578329791        82  -2.67  141.30          Vanimo
# 8          22      PE  1578329237        54 -11.10  -77.61         Hualmay
# 9           1      US  1578329791        62  39.31  -74.98  Port Elizabeth
#
#      Temp  Wind
# 0  282.59  0.89
# 1  258.15  4.10
# 2  297.15  2.10
# 3  279.15  2.60
# 4  295.37  2.60
# 5  299.15  2.42
# 6  290.23  4.17
# 7  301.30  4.99
# 8  299.82  4.97
# 9  284.26  3.60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df.plot(x= 'Lat', y='Temp', kind='scatter', s=40, color = '#4B92C2', edgecolor='black', grid=True)
plt.title("City Latitude vs. Max Temperature (" + today + ")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the Figure
plt.savefig("lat_vs_temp.png", dpi=100)

# Show the Figure
plt.show()

# %% [markdown]
# #### Plot Analysis
#
# It's pretty clear from this plot that the closer you get to the ecuator the hotter it gets. Interestingly, some cities south of the Ecuator (e.g. Griffith, AU) can even get hotter, whereas north of the Ecuador it doesn't seem to ever be the case.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
df.plot(x= 'Lat', y='Humidity', kind='scatter', s=40, color = '#4B92C2', edgecolor='black', grid=True)
plt.title("City Latitude vs. Humidity  (" + today + ")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the Figure
plt.savefig("lat_vs_humidity.png", dpi=100)

# Show the Figure
plt.show()

# %% [markdown]
# #### Plot Analysis
#
# From this sample, there doesn't seem to be a strong correlation between humidity and proximity to the ecuator. In fact, there seems to be a slightly larger cluster of cities north of the ecuator with higher himidity percentage.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
df.plot(x= 'Lat', y='Cloudiness', kind='scatter', s=40, color = '#4B92C2', edgecolor='black', grid=True)
plt.title("City Latitude vs. Cloudiness (" + today + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the Figure
plt.savefig("lat_vs_cloudiness.png", dpi=100)

# Show the Figure
plt.show()

# %% [markdown]
# #### Plot Analysis
#
# From this sample—as of today—we can observse several clusters cloudiness across different latitudes. One of the most visible ones is at the level of the ecuator—and north of it—where you can see that skies are pretty clear.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
df.plot(x= 'Lat', y='Wind', kind='scatter', s=40, color = '#4B92C2', edgecolor='black', grid=True)
plt.title("City Latitude vs. Wind Speed (" + today + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speend (mph)")

# Save the Figure
plt.savefig("lat_vs_wind.png", dpi=100)

# Show the Figure
plt.show()

# %% [markdown]
# #### Plot Analysis
#
# From this sample—as of today—there doesn't seem to be a correlation between latitude and wind speed. In fact, most cities fall underneath the 5mph threshold, regardless of the latitude.
